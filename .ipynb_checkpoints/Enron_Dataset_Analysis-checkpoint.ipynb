# %% [markdown]
# # Enron Dataset Analysis
# <hr>
# **Author:**
#
# The Enron email dataset contains approximately 500,000 emails generated by employees of the Enron Corporation. It was obtained by the Federal Energy Regulatory Commission during its investigation of Enron's collapse. In the following analysis, I'm trying to find out any suspicious behavior among users and any correlation with the amount of emails sent or the length of the emails sent.

# %%
import pandas as pd
import nltk
import re
import email
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('enron').getOrCreate()

# %% [markdown]
# ### Loading enron dataset

# %%
data = pd.read_csv('./emails.csv')
data.shape
# Out:
# (517401, 2)

# %% [markdown]
# Over half million rows and two columns.

# %%
data.columns
# Out:
# Index(['file', 'message'], dtype='object')

# %%
print(data['message'][0])
# Out:
# Message-ID: <18782981.1075855378110.JavaMail.evans@thyme>
# Date: Mon, 14 May 2001 16:39:00 -0700 (PDT)
# From: phillip.allen@enron.com
# To: tim.belden@enron.com
# Subject:
# Mime-Version: 1.0
# Content-Type: text/plain; charset=us-ascii
# Content-Transfer-Encoding: 7bit
# X-From: Phillip K Allen
# X-To: Tim Belden <Tim Belden/Enron@EnronXGate>
# X-cc:
# X-bcc:
# X-Folder: \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Sent Mail
# X-Origin: Allen-P
# X-FileName: pallen (Non-Privileged).pst
#
# Here is our forecast

# %% [markdown]
# Looks like the message has the [RFC822](https://www.w3.org/Protocols/rfc822/) message protocol. Researching in [Kaggle](http://www.kaggle.com) the Enron dataset I found that [Python](http://www.python.org) has a library to parse messages in RFC822 format and the documentation is [here](https://docs.python.org/3.4/library/email.message.html#email.message.Message.walk). Since the `message` column has the most useful content, lets start working with that column.

# %% [markdown]
# Parsing the string into an email object - documentation [here](https://docs.python.org/3.4/library/email.parser.html?highlight=message_from_string#email.message_from_string).

# %%
emails = list(map(email.message_from_string, data['message']))

# %%
print(len(emails))
emails[0]
# Out:
# 517401

# %% [markdown]
# Now I have each row in a email object.

# %% [markdown]
# ### Transforming email object into data frame.

# %%
print(emails[0])
# Out:
# Message-ID: <18782981.1075855378110.JavaMail.evans@thyme>
# Date: Mon, 14 May 2001 16:39:00 -0700 (PDT)
# From: phillip.allen@enron.com
# To: tim.belden@enron.com
# Subject:
# Mime-Version: 1.0
# Content-Type: text/plain; charset=us-ascii
# Content-Transfer-Encoding: 7bit
# X-From: Phillip K Allen
# X-To: Tim Belden <Tim Belden/Enron@EnronXGate>
# X-cc:
# X-bcc:
# X-Folder: \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Sent Mail
# X-Origin: Allen-P
# X-FileName: pallen (Non-Privileged).pst
#
# Here is our forecast

# %% [markdown]
# The email parser would take each row header as key (`Message-ID`, `Date`, `From`, `To`, etc). We are going to use those keys to iterate over each row object and extract the data. Each key will become column names and the respective values as rows.

# %%
emails_key = emails[0].keys()
emails_key
# Out:
# ['Message-ID',
#  'Date',
#  'From',
#  'To',
#  'Subject',
#  'Mime-Version',
#  'Content-Type',
#  'Content-Transfer-Encoding',
#  'X-From',
#  'X-To',
#  'X-cc',
#  'X-bcc',
#  'X-Folder',
#  'X-Origin',
#  'X-FileName']

# %% [markdown]
# The actual content of the email doesn't have a key therefore that key is not present in the `list`. We are going to get that content with `get_payload()` method from the email package.

# %%
df = pd.DataFrame()
for key in emails_key:
    df[key] = [col_value[key] for col_value in emails]
    df['email_body'] = [email_content.get_payload() for email_content in emails]
    df['user'] = data['file'].map(lambda file_path: file_path.split('/')[0])

# %%
df.head(1)
# Out:
#                                       Message-ID                 email_body  \
# 0  <18782981.1075855378110.JavaMail.evans@thyme>  Here is our forecast\n\n
#
#       user                                   Date                     From  \
# 0  allen-p  Mon, 14 May 2001 16:39:00 -0700 (PDT)  phillip.allen@enron.com
#
#                      To Subject Mime-Version                  Content-Type  \
# 0  tim.belden@enron.com                  1.0  text/plain; charset=us-ascii
#
#   Content-Transfer-Encoding           X-From  \
# 0                      7bit  Phillip K Allen
#
#                                        X-To X-cc X-bcc  \
# 0  Tim Belden <Tim Belden/Enron@EnronXGate>
#
#                                             X-Folder X-Origin  \
# 0  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
#
#                     X-FileName
# 0  pallen (Non-Privileged).pst

# %%
df.drop(['Content-Transfer-Encoding', 'Content-Type', 'Mime-Version'], axis=1, inplace=True)
df.head(1)
# Out:
#                                       Message-ID                 email_body  \
# 0  <18782981.1075855378110.JavaMail.evans@thyme>  Here is our forecast\n\n
#
#       user                                   Date                     From  \
# 0  allen-p  Mon, 14 May 2001 16:39:00 -0700 (PDT)  phillip.allen@enron.com
#
#                      To Subject           X-From  \
# 0  tim.belden@enron.com          Phillip K Allen
#
#                                        X-To X-cc X-bcc  \
# 0  Tim Belden <Tim Belden/Enron@EnronXGate>
#
#                                             X-Folder X-Origin  \
# 0  \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
#
#                     X-FileName
# 0  pallen (Non-Privileged).pst

# %%
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
df.head(1)
# Out:
#                                       Message-ID                 email_body  \
# 0  <18782981.1075855378110.JavaMail.evans@thyme>  Here is our forecast\n\n
#
#       user                Date                     From                    To  \
# 0  allen-p 2001-05-14 23:39:00  phillip.allen@enron.com  tim.belden@enron.com
#
#   Subject           X-From                                      X-To X-cc  \
# 0          Phillip K Allen  Tim Belden <Tim Belden/Enron@EnronXGate>
#
#   X-bcc                                           X-Folder X-Origin  \
# 0        \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...  Allen-P
#
#                     X-FileName
# 0  pallen (Non-Privileged).pst

# %%
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
sb.set()

# %%
dims = (11.7, 8.2)
fig, ax = plt.subplots(figsize=dims)
ax.figure.suptitle('Email Count By Year', fontsize=20)
ax = df.groupby(df['Date'].dt.year)['email_body'].count().plot()
ax.set_xlabel('Year', fontsize=15)
ax.set_ylabel('# Emails', fontsize=15)
# Out:
# Text(0,0.5,'# Emails')

# %% [markdown]
# It is a spike in the amount of emails around 2001. Based on [this article](http://www.corpwatch.org/article.php?id=2278), that is the time when Enron discloses it has overstated its earnings by $600 million, dating back to 1997.

# %% [markdown]
# ### Analyzing counts

# %%
user_count = df['user'].value_counts().to_frame()
user_count.reset_index(inplace=True)
user_count.rename(columns={'index': 'User', 'user': 'User Count'}, inplace=True)
user_count.sort_values('User Count', ascending=False, inplace=True)
user_count.head()
# Out:
#          User  User Count
# 0  kaminski-v       28465
# 1  dasovich-j       28234
# 2      kean-s       25351
# 3      mann-k       23381
# 4     jones-t       19950

# %%
user_count['User Count'].sum()
# Out:
# 517401

# %% [markdown]
# The `From` and `file` which became `user` have the same count.

# %%
kaminski = df[['user', 'From', 'X-Origin']]
kaminski = kaminski[kaminski['user'] == 'kaminski-v']

# %%
print(kaminski.columns)
kaminski.shape
# Out:
# Index(['user', 'From', 'X-Origin'], dtype='object')
# (28465, 3)

# %%
print(f'Same user => {kaminski["user"].unique()[0]}')
print(f'With two origin accounts => {kaminski["X-Origin"].unique()[0]}, {kaminski["X-Origin"].unique()[1]}')
print(f'Used {kaminski["From"].nunique()} different email addresses to send emails.')
# Out:
# Same user => kaminski-v
# With two origin accounts => Kaminski-V, KAMINSKI-V
# Used 1503 different email addresses to send emails.

# %% [markdown]
# ### TODO:
# - What `X-Origin` means.

# %%
sub_df = df[['user', 'From', 'X-Origin']]
sub_df = sub_df.groupby('user').nunique()
sub_df.rename_axis('User', inplace=True)
sub_df = sub_df.rename(columns={
    'user': 'User Count'
})
sub_df.reset_index(inplace=True)
sub_df = sub_df.rename(columns={
    'user': 'User'
})
sub_df.sort_values('From', ascending=False)
# Out:
#              User  User Count  From  X-Origin
# 63          lay-k           1  2200         2
# 55     kaminski-v           1  1503         2
# 19     dasovich-j           1  1146         3
# 132      taylor-m           1   975         1
# 118    skilling-j           1   919         4
# 114  shackleton-s           1   814         2
# 56         kean-s           1   751         3
# 54        jones-t           1   735         2
# 60      kitchen-l           1   684         2
# 7          beck-s           1   662         2
# 85        nemec-g           1   611         2
# 12     campbell-l           1   608         2
# 42     haedicke-m           1   580         2
# 29       farmer-d           1   576         2
# 116     shapiro-r           1   526         2
# 108     sanders-r           1   511         1
# 112       scott-s           1   493         2
# 62     lavorato-j           1   480         3
# 65        lewis-a           1   462         2
# 6      baughman-d           1   430         4
# 102      rogers-b           1   415         2
# 104       sager-e           1   403         2
# 36      germany-c           1   401         2
# 72         mann-k           1   396         2
# 52        hyatt-k           1   381         1
# 125     steffes-j           1   369         1
# 11          buy-r           1   363         2
# 144    williams-j           1   358         2
# 45     hayslett-r           1   355         2
# 138      watson-k           1   345         1
# ..            ...         ...   ...       ...
# 61   kuykendall-t           1   108         2
# 130    swerzbin-m           1   108         1
# 77        mckay-b           1   103         3
# 86        panus-s           1   100         1
# 83       motley-m           1    97         1
# 135    townsend-j           1    97         2
# 15    causholli-m           1    96         1
# 59         king-j           1    95         3
# 4        bailey-s           1    92         2
# 124     stclair-c           1    91         2
# 31       forney-j           1    90         2
# 33         gang-l           1    77         1
# 34          gay-r           1    76         2
# 3        badeer-r           1    70         1
# 99         ring-a           1    68         2
# 149    zufferli-j           1    67         2
# 66       linder-e           1    66         1
# 80      merriss-s           1    65         1
# 88      pereira-s           1    63         1
# 121     solberg-g           1    60         1
# 127     stokley-c           1    57         1
# 81       meyers-a           1    55         1
# 107     sanchez-m           1    55         2
# 22     delainey-d           1    42         2
# 119     slinger-r           1    41         1
# 122       south-s           1    39         1
# 94       quenet-j           1    29         1
# 101    rodrique-r           1    22         1
# 90       phanis-s           1    20         1
# 24      dickson-s           1     3         1
#
# [150 rows x 4 columns]

# %%
user_with_most_from_emails = sub_df[sub_df['From'] > 500]
user_with_most_from_emails.sort_values('From', ascending=False)
# Out:
#              User  User Count  From  X-Origin
# 63          lay-k           1  2200         2
# 55     kaminski-v           1  1503         2
# 19     dasovich-j           1  1146         3
# 132      taylor-m           1   975         1
# 118    skilling-j           1   919         4
# 114  shackleton-s           1   814         2
# 56         kean-s           1   751         3
# 54        jones-t           1   735         2
# 60      kitchen-l           1   684         2
# 7          beck-s           1   662         2
# 85        nemec-g           1   611         2
# 12     campbell-l           1   608         2
# 42     haedicke-m           1   580         2
# 29       farmer-d           1   576         2
# 116     shapiro-r           1   526         2
# 108     sanders-r           1   511         1

# %% [markdown]
# My hunch is that a single user is utilizing multiple email addresses to send emails to hide identity. If that is correct, the CEO Kenneth Lee Lay has the most amount of `From` emails follow by Vincent Julian Kaminski the Managing Director for Research.

# %%
df2 = df[['user', 'From', 'email_body']]
df2.loc[:, 'email_body'] = df2.loc[:, 'email_body'].str.replace('\W', ' ')
df2
# Out:
# /Users/gdiaz/notebooks/enron/lib/python3.6/site-packages/pandas/core/indexing.py:601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#               user                     From  \
# 0          allen-p  phillip.allen@enron.com
# 1          allen-p  phillip.allen@enron.com
# 2          allen-p  phillip.allen@enron.com
# 3          allen-p  phillip.allen@enron.com
# 4          allen-p  phillip.allen@enron.com
# 5          allen-p  phillip.allen@enron.com
# 6          allen-p  phillip.allen@enron.com
# 7          allen-p  phillip.allen@enron.com
# 8          allen-p  phillip.allen@enron.com
# 9          allen-p  phillip.allen@enron.com
# 10         allen-p  phillip.allen@enron.com
# 11         allen-p  phillip.allen@enron.com
# 12         allen-p  phillip.allen@enron.com
# 13         allen-p  phillip.allen@enron.com
# 14         allen-p  phillip.allen@enron.com
# 15         allen-p  phillip.allen@enron.com
# 16         allen-p  phillip.allen@enron.com
# 17         allen-p  phillip.allen@enron.com
# 18         allen-p  phillip.allen@enron.com
# 19         allen-p  phillip.allen@enron.com
# 20         allen-p  phillip.allen@enron.com
# 21         allen-p  phillip.allen@enron.com
# 22         allen-p  phillip.allen@enron.com
# 23         allen-p  phillip.allen@enron.com
# 24         allen-p  phillip.allen@enron.com
# 25         allen-p  phillip.allen@enron.com
# 26         allen-p  phillip.allen@enron.com
# 27         allen-p  phillip.allen@enron.com
# 28         allen-p  phillip.allen@enron.com
# 29         allen-p  phillip.allen@enron.com
# ...            ...                      ...
# 517371  zufferli-j  john.zufferli@enron.com
# 517372  zufferli-j  john.zufferli@enron.com
# 517373  zufferli-j  john.zufferli@enron.com
# 517374  zufferli-j  john.zufferli@enron.com
# 517375  zufferli-j  john.zufferli@enron.com
# 517376  zufferli-j  john.zufferli@enron.com
# 517377  zufferli-j  john.zufferli@enron.com
# 517378  zufferli-j  john.zufferli@enron.com
# 517379  zufferli-j  john.zufferli@enron.com
# 517380  zufferli-j  john.zufferli@enron.com
# 517381  zufferli-j  john.zufferli@enron.com
# 517382  zufferli-j  john.zufferli@enron.com
# 517383  zufferli-j  john.zufferli@enron.com
# 517384  zufferli-j  john.zufferli@enron.com
# 517385  zufferli-j  john.zufferli@enron.com
# 517386  zufferli-j  john.zufferli@enron.com
# 517387  zufferli-j  john.zufferli@enron.com
# 517388  zufferli-j  john.zufferli@enron.com
# 517389  zufferli-j  john.zufferli@enron.com
# 517390  zufferli-j  john.zufferli@enron.com
# 517391  zufferli-j  john.zufferli@enron.com
# 517392  zufferli-j  john.zufferli@enron.com
# 517393  zufferli-j  john.zufferli@enron.com
# 517394  zufferli-j  john.zufferli@enron.com
# 517395  zufferli-j  john.zufferli@enron.com
# 517396  zufferli-j  john.zufferli@enron.com
# 517397  zufferli-j  john.zufferli@enron.com
# 517398  zufferli-j  john.zufferli@enron.com
# 517399  zufferli-j  john.zufferli@enron.com
# 517400  zufferli-j  john.zufferli@enron.com
#
#                                                email_body
# 0                                 Here is our forecast
# 1       Traveling to have a business meeting takes the...
# 2                          test successful   way to go
# 3       Randy    Can you send me a schedule of the sal...
# 4                     Let s shoot for Tuesday at 11 45
# 5       Greg    How about either next Tuesday or Thurs...
# 6       Please cc the following distribution list with...
# 7                        any morning between 10 and 11 30
# 8       1  login   pallen pw  ke9davis   I don t think...
# 9                              Forwarded by Phillip K ...
# 10      Mr  Buckner    For delivered gas behind San Di...
# 11      Lucy    Here are the rentrolls      Open them ...
# 12                             Forwarded by Phillip K ...
# 13                             Forwarded by Phillip K ...
# 14      Dave     Here are the names of the west desk m...
# 15                   Paula    35 million is fine  Phillip
# 16                             Forwarded by Phillip K ...
# 17      Tim   mike grigsby is having problems with acc...
# 18                             Forwarded by Phillip K ...
# 19                             Forwarded by Phillip K ...
# 20      Brenda   Please use the second check as the Oc...
# 21      I think Fletch has a good CPA   I am still doi...
# 22      Brenda    Please use the second check as my Oc...
# 23                             Forwarded by Phillip K ...
# 24      Liane    As we discussed yesterday  I am conce...
# 25                             Forwarded by Phillip K ...
# 26                             Forwarded by Phillip K ...
# 27                             Forwarded by Phillip K ...
# 28      Reagan   Just wanted to give you an update   I...
# 29      Nymex expiration is during this time frame   P...
# ...                                                   ...
# 517371  Dad asked if I wanted to lend you some money b...
# 517372  I am interested in a program for myself   I am...
# 517373  yes        Original Message      From   Dupuy ...
# 517374  Its OK  John Zufferli        Original Message ...
# 517375  you can increase the direct sale to include De...
# 517376  You should talk to Jess about that  she is due...
# 517377            Original Message      From   Cappell...
# 517378  Here is the update list that you requested  Mi...
# 517379  i am waiting on the conference call and no one...
# 517380          Original Message      From   Livia_Zuf...
# 517381          Original Message      From   McKeel  R...
# 517382  nothing new here  when is your flight  have yo...
# 517383   In addition to a list of software and systems...
# 517384  Please set up access for the digital certifica...
# 517385          Original Message      From    Ritter  ...
# 517386          Original Message      From    John Ber...
# 517387          Original Message      From   Milnthorp...
# 517388   Here is the info for the commercial staff  Jo...
# 517389   Enron is willing to perform the operation und...
# 517390  I will have 4 books   CAND MGMT BAS for all AE...
# 517391          Original Message      From   Reeves  K...
# 517392  Nicole and everyone  I think the directory is ...
# 517393  not yet  rob has been in the court house all d...
# 517394          Original Message      From    Lerner  ...
# 517395  very busy  jess is ok just scared        Origi...
# 517396  This is a trade with OIL SPEC HEDGE NG  John L...
# 517397  Some of my position is with the Alberta Term b...
# 517398  2        Original Message      From   Doucet  ...
# 517399  Analyst     Rank  Stephane Brodeur   1 Chad Cl...
# 517400  i think the YMCA has a class that is for peopl...
#
# [517401 rows x 3 columns]

# %%
df2.to_csv('user_and_emails.csv', index=False)

# %% [markdown]
# ### Importing PySpark functions, features, types

# %%
data = pd.read_csv('./user_and_emails.csv')
data.head()
# Out:
#       user                     From  \
# 0  allen-p  phillip.allen@enron.com
# 1  allen-p  phillip.allen@enron.com
# 2  allen-p  phillip.allen@enron.com
# 3  allen-p  phillip.allen@enron.com
# 4  allen-p  phillip.allen@enron.com
#
#                                           email_body
# 0                            Here is our forecast
# 1  Traveling to have a business meeting takes the...
# 2                     test successful   way to go
# 3  Randy    Can you send me a schedule of the sal...
# 4                Let s shoot for Tuesday at 11 45

# %%
data['email_to_words'] = data.apply(lambda row: nltk.word_tokenize(row['email_body']), axis=1)

# %%
data['email_length'] = data.apply(lambda row: len(row['email_to_words']), axis=1)

# %%
data.head()
# Out:
#       user                     From  \
# 0  allen-p  phillip.allen@enron.com
# 1  allen-p  phillip.allen@enron.com
# 2  allen-p  phillip.allen@enron.com
# 3  allen-p  phillip.allen@enron.com
# 4  allen-p  phillip.allen@enron.com
#
#                                           email_body  \
# 0                            Here is our forecast
# 1  Traveling to have a business meeting takes the...
# 2                     test successful   way to go
# 3  Randy    Can you send me a schedule of the sal...
# 4                Let s shoot for Tuesday at 11 45
#
#                                       email_to_words  email_length
# 0                          [Here, is, our, forecast]             4
# 1  [Traveling, to, have, a, business, meeting, ta...           140
# 2                    [test, successful, way, to, go]             5
# 3  [Randy, Can, you, send, me, a, schedule, of, t...            34
# 4          [Let, s, shoot, for, Tuesday, at, 11, 45]             8

# %%
unique_df = data[['user', 'From', 'email_length']]

# %%
unique_from = unique_df.groupby('user').nunique('From')

# %%
email_length_sum = unique_df.groupby('user').agg({'email_length': 'sum'})

# %%
corr_df = pd.concat([unique_from, email_length_sum], axis=1)

# %%
corr_df.columns = ['user_count', 'from_count', 'email_length', 'sum_email_length']

# %%
corr_df.drop(['user_count', 'email_length'], axis=1, inplace=True)

# %%
corr_df.head()
# Out:
#           from_count  sum_email_length
# user
# allen-p          182            576390
# arnold-j         308           1388679
# arora-h          178            242933
# badeer-r          70            243464
# bailey-s          92             82412

# %%
sb.lmplot(x='sum_email_length', y='from_count', data=corr_df, size=8, aspect=2)

# %% [markdown]
# Seems that is some correlation between the length of the email and the amount of emails used to send emails by user. Notice that email_length values are scientific notation `e7`.
